# %% [markdown]
# ## Build an entire pipeline/package?
# * Builds RAG application
#     * Have dataset ready to create vector index (this is situational based on application)
#     * Use fraction of same dataset to create synthetic dataset using RAGS
#     * Runs the RAG application and produces an 'answer' column
#     * Runs RAGAS and evaluates based on specified metric
#     * Gives summary
# * Update this to try out different RAG formulations and compare eval

# %% [markdown]
# ### Imports and API Keys

# %%
import pandas as pd
import os

from dotenv import load_dotenv, find_dotenv

import warnings
warnings.filterwarnings('ignore')

from langchain import hub
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import ConversationalRetrievalChain
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.document_loaders import DataFrameLoader
from langchain.vectorstores import Chroma

from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
)

from datasets import Dataset

# %% [markdown]
# **Note** How do we use Langchain trace effectively?

# %%
_ = load_dotenv(find_dotenv())

os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'

os.environ['LANGCHAIN_API_KEY'] = os.environ['LANGCHAIN_API_KEY']
os.environ['OPENAI_API_KEY'] = os.environ['OPENAI_API_KEY']

# %% [markdown]
# ### Read in the dataset
# **Note**: There could be nuances here (in a proper package/software): Add in connectors etc.

# %%
### Read in dataset (all ~66k cosmology paper abstracts and titles)

df_cosmo = pd.read_csv('astro_rag/arxiv_astro-ph_data_cosmo.csv')    
df_cosmo.head()
# Out:
#           id                                              title  \
# 0  0705.2176  Gravitational particle production in braneworl...
# 1  0705.2299  Time evolution of T_{\mu\nu} and the cosmologi...
# 2  0705.3289  Helium abundance in galaxy clusters and Sunyae...
# 3  0705.4139       Our Peculiar Motion Away from the Local Void
# 4  0707.1351  Inverse approach to Einstein's equations for f...
#
#                                             abstract  \
# 0  Gravitational particle production in time vari...
# 1  We study the cosmic time evolution of an effec...
# 2  It has long been suggested that helium nuclei ...
# 3  The peculiar velocity of the Local Group of ga...
# 4  We expand previous work on an inverse approach...
#
#                                      categories  \
# 0                      hep-ph astro-ph.CO gr-qc
# 1                      hep-ph astro-ph.CO gr-qc
# 2  astro-ph astro-ph.CO astro-ph.HE astro-ph.IM
# 3                          astro-ph astro-ph.CO
# 4                             gr-qc astro-ph.CO
#
#                                             cat_text  \
# 0  High Energy Physics - Phenomenology, Cosmology...
# 1  High Energy Physics - Phenomenology, Cosmology...
# 2  Astrophysics, Cosmology and Nongalactic Astrop...
# 3  Astrophysics, Cosmology and Nongalactic Astrop...
# 4  General Relativity and Quantum Cosmology, Cosm...
#
#                                        prepared_text
# 0  Gravitational particle production in braneworl...
# 1  Time evolution of T_{\mu\nu} and the cosmologi...
# 2  Helium abundance in galaxy clusters and Sunyae...
# 3  Our Peculiar Motion Away from the Local Void \...
# 4  Inverse approach to Einstein's equations for f...

# %%
df_cosmo.shape
# Out:
# (66103, 6)

# %% [markdown]
# For this example, to cut down time, let us only use the categories that are just 'astro-ph.CO', so no cross-disciplinary papers; just 'Cosmology and Nongalactic Astrophysics'

# %%
df_cosmo = df_cosmo.loc[df_cosmo['categories']=='astro-ph.CO']
df_cosmo.reset_index(inplace=True, drop=True)

df_cosmo.head()
# Out:
#           id                                              title  \
# 0  0901.0173  Non-Minimal Quintessence With Nearly Flat Pote...
# 1  0901.0189  Robust determination of the major merger fract...
# 2  0901.0245  Neutrino Masses, Dark Energy and the Gravitati...
# 3  0901.0285  Impact of Instrumental Systematic Contaminatio...
# 4  0901.0286  Tracing the Reionization-Epoch Intergalactic M...
#
#                                             abstract   categories  \
# 0  We consider Brans-Dicke type nonminimally coup...  astro-ph.CO
# 1  (Abridged) We measure the fraction of galaxies...  astro-ph.CO
# 2  We study the constraints which the next genera...  astro-ph.CO
# 3  In this paper, we study the effects of instrum...  astro-ph.CO
# 4  IGM metal absorption lines observed in z>6 spe...  astro-ph.CO
#
#                                  cat_text  \
# 0  Cosmology and Nongalactic Astrophysics
# 1  Cosmology and Nongalactic Astrophysics
# 2  Cosmology and Nongalactic Astrophysics
# 3  Cosmology and Nongalactic Astrophysics
# 4  Cosmology and Nongalactic Astrophysics
#
#                                        prepared_text
# 0  Non-Minimal Quintessence With Nearly Flat Pote...
# 1  Robust determination of the major merger fract...
# 2  Neutrino Masses, Dark Energy and the Gravitati...
# 3  Impact of Instrumental Systematic Contaminatio...
# 4  Tracing the Reionization-Epoch Intergalactic M...

# %%
df_cosmo.shape
# Out:
# (21674, 6)

# %% [markdown]
# So now we have ~22k rows in the dataset. Let's build both the vector index using Chroma and the synthetic dataset using RAGAS

# %% [markdown]
# ### Create vector index

# %% [markdown]
# The embedding model used isn't a currently high-ranked one (https://huggingface.co/spaces/mteb/leaderboard), this example is just for prototyping

# %%
# Get the embedding model

model_name = "sentence-transformers/all-MiniLM-l6-v2" 
model_kwargs = {"device": "cpu"} # Since we are running on local machine, we will use CPU

embeddings = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)

# %%
# Create a DataFrameLoader
loader = DataFrameLoader(df_cosmo, page_content_column='prepared_text')
arxiv_documents = loader.load()

arxiv_documents[0]
# Out:
# Document(page_content="Non-Minimal Quintessence With Nearly Flat Potential \n We consider Brans-Dicke type nonminimally coupled scalar field as a candidate for dark energy. In the conformally transformed Einstein's frame, our model is similar to {\\it coupled quintessence} model. In such models, we consider potentials for the scalar field which satisfy the slow-roll conditions: $[(1/V)(dV/d\\phi)]^2 << 1$ and $(1/V)(d^2V/d\\phi^2) << 1$. For such potentials, we show that the equation of state for the scalar field can be described by a universal behaviour, provided the scalar field rolls only in the flat part of the potentials where the slow-roll conditions are satisfied. Our work generalizes the previous work by Scherrer and Sen \\cite{scherrer} for minimally coupled scalar field case. We have also studied the observational constraints on the model parameters considering the Supernova and BAO observational data.", metadata={'id': '0901.0173', 'title': 'Non-Minimal Quintessence With Nearly Flat Potential', 'abstract': "We consider Brans-Dicke type nonminimally coupled scalar field as a candidate for dark energy. In the conformally transformed Einstein's frame, our model is similar to {\\it coupled quintessence} model. In such models, we consider potentials for the scalar field which satisfy the slow-roll conditions: $[(1/V)(dV/d\\phi)]^2 << 1$ and $(1/V)(d^2V/d\\phi^2) << 1$. For such potentials, we show that the equation of state for the scalar field can be described by a universal behaviour, provided the scalar field rolls only in the flat part of the potentials where the slow-roll conditions are satisfied. Our work generalizes the previous work by Scherrer and Sen \\cite{scherrer} for minimally coupled scalar field case. We have also studied the observational constraints on the model parameters considering the Supernova and BAO observational data.", 'categories': 'astro-ph.CO', 'cat_text': 'Cosmology and Nongalactic Astrophysics'})

# %% [markdown]
# **Note** We can implement more refined chunking strategies here; another thing we can use to evaluate the RAG application, i.e.
# * Keep the vector indexing strategy the same, change prompting strategy -> evaluate
# * Or Change indexing strategy, keep prompting same -> evaluate

# %%
### Split the documents into smaller chunks

splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20) 
# Keeping this small initially, since these are just abstracts, not full paper text

chunked_docs = splitter.split_documents(arxiv_documents)

# %% [markdown]
# **Note** Parametrize this flow as much as possible; persist_directory, chunking params etc

# %%
### Create the vectordb and persist it 
# Takes < 15 mins to run on a Macbook M2 Pro 2023

# vectordb = Chroma.from_documents(documents=chunked_docs, embedding=embeddings, persist_directory="arxiv_cosmo_chroma_db_22k")
# vectordb.persist()

# %%
# If you want to load the persisted vectordb

vectordb = Chroma(persist_directory='./arxiv_cosmo_chroma_db_22k', embedding_function=embeddings)
retriever = vectordb.as_retriever()

# %% [markdown]
# ### Create synthetic dataset using RAGAS

# %%
df_sample = df_cosmo.sample(1000, random_state=42) # 1k rows at random from original 22k dataset
df_sample.reset_index(drop=True, inplace=True)
df_sample.head()
# Out:
#            id                                              title  \
# 0  1503.06036  Redshift-space equal-time angular-averaged con...
# 1  1910.04171  Weak Lensing Minima and Peaks: Cosmological Co...
# 2  1912.06601  Lensing-like tensions in the Planck legacy rel...
# 3   1403.1089  A comparison of CMB Angular Power Spectrum Est...
# 4   1102.2234  Gas inflows, star formation and metallicity ev...
#
#                                             abstract   categories  \
# 0  We present the redshift-space generalization o...  astro-ph.CO
# 1  We present a novel statistic to extract cosmol...  astro-ph.CO
# 2  We analyze the final release of the Planck sat...  astro-ph.CO
# 3  In the context of cosmic microwave background ...  astro-ph.CO
# 4  It has been known since many decades that gala...  astro-ph.CO
#
#                                  cat_text  \
# 0  Cosmology and Nongalactic Astrophysics
# 1  Cosmology and Nongalactic Astrophysics
# 2  Cosmology and Nongalactic Astrophysics
# 3  Cosmology and Nongalactic Astrophysics
# 4  Cosmology and Nongalactic Astrophysics
#
#                                        prepared_text
# 0  Redshift-space equal-time angular-averaged con...
# 1  Weak Lensing Minima and Peaks: Cosmological Co...
# 2  Lensing-like tensions in the Planck legacy rel...
# 3  A comparison of CMB Angular Power Spectrum Est...
# 4  Gas inflows, star formation and metallicity ev...

# %%
loader = DataFrameLoader(df_sample, page_content_column='prepared_text')
documents_for_synthesis = loader.load()

# %% [markdown]
# **Note** Many things here that can/should be experimented with:
# * Generator and Critic LLMs used
# * Embeddings
# * Distributions (for different use-cases)
# * Compare with another generation method (such as Bonito)

# %%
# generator with openai models
generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
critic_llm = ChatOpenAI(model="gpt-4")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

# generate testset
# Took about $5 to generate 
# testset = generator.generate_with_langchain_docs(documents_for_synthesis, test_size=25, \
                                                #  distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25})

# Commenting out to prevent running accidentally

# %%
# testset.test_data[0]

# %%
# df_test = testset.to_pandas()
# df_test

# %%
# testset.save('cosmo_ragas_testset_25.json')
# df_test.to_csv('cosmo_ragas_testset_25.csv', index=False) # Save for future use

# %%
df_test = pd.read_csv('cosmo_ragas_testset_25.csv')
df_test
# Out:
#                                              question  \
# 0   What is the potential of future SKA-era PTAs i...
# 1   What are the potential constraints on the natu...
# 2   How is a temperature map used to derive an ang...
# 3   What are the star formation properties in the ...
# 4   What is the predicted red excess in galaxy col...
# 5   How can upcoming photometric large scale struc...
# 6   What are the cosmological constraints obtained...
# 7   What is the average fraction of cold gas relat...
# 8   What is the relationship between rotation curv...
# 9   What is the focus of the XMM-Newton Wide-Field...
# 10  What were the results of the observations in t...
# 11  How does the patchiness in the spatial distrib...
# 12  How can future SKA-era PTAs contribute to dete...
# 13  How does $1/f$ noise impact SKA intensity mapp...
# 14  How does recovering a temperature map from the...
# 15  What is the impact of high dust depletion on c...
# 16  What is the impact of the environment on galax...
# 17  What cosmological parameters are obtained from...
# 18  What can future SKA-era PTAs do to detect supe...
# 19  What can we learn about dark energy from upcom...
# 20  What explains the lower amplitudes of the low ...
# 21  What factors determine the pattern speed of th...
# 22  What is the optimal Doppler parameter for the ...
# 23  What is the optimal survey strategy for weak l...
# 24  How does redshift affect the detectability of ...
#
#                                              contexts  \
# 0   ['Prospects for Constraining interacting dark ...
# 1   ['Strong Lensing Time Delay Constraints on Dar...
# 2   ['New evidence for lack of CMB power on large ...
# 3   ['Star Formation Properties in Barred Galaxies...
# 4   ['Groups of two galaxies in SDSS: implications...
# 5   ['Optimising cosmic shear surveys to measure m...
# 6   ['Weak lensing from space: first cosmological ...
# 7   ["High molecular gas fractions in normal massi...
# 8   ['Halo Gas and Galaxy Disk Kinematics Derived ...
# 9   ['The XMM-Newton Wide-Field Survey in the COSM...
# 10  ['Molecular Gas in Intermediate Redshift ULIRG...
# 11  ['Inevitable imprints of patchy reionization o...
# 12  ['Prospects for Constraining interacting dark ...
# 13  ['Impact of $1/f$ noise on cosmological parame...
# 14  ['New evidence for lack of CMB power on large ...
# 15  ['Direct Evidence of Cold Gas in DLA 0812+32B ...
# 16  ['Groups of two galaxies in SDSS: implications...
# 17  ['Dark Energy Survey Year 1 Results: Cosmologi...
# 18  ['Prospects for Constraining interacting dark ...
# 19  ['Strong Lensing Time Delay Constraints on Dar...
# 20  ['New evidence for lack of CMB power on large ...
# 21  ['The relation between dynamics and star forma...
# 22  ['Direct Evidence of Cold Gas in DLA 0812+32B ...
# 23  ['Probing the accelerating Universe with radio...
# 24  ['Deuterated species in extragalactic star-for...
#
#                                          ground_truth evolution_type  \
# 0   The future SKA-era PTAs have the potential to ...         simple
# 1                                                 NaN         simple
# 2   A temperature map is used to derive an angular...         simple
# 3   Under the effects of both a stellar bar and a ...         simple
# 4                 0.15,$\pm$,0.01 and 0.14,$\pm$,0.01         simple
# 5   We consider how upcoming photometric large sca...         simple
# 6   The cosmological constraints obtained from the...         simple
# 7   The average fraction of cold gas relative to t...         simple
# 8   The majority of the absorption velocities of M...         simple
# 9   The focus of the XMM-Newton Wide-Field Survey ...         simple
# 10                                                NaN         simple
# 11  The patchiness in the spatial distribution of ...         simple
# 12  Future SKA-era PTAs can contribute to detectin...      reasoning
# 13  $1/f$ noise degrades the projected constraints...      reasoning
# 14                                                NaN      reasoning
# 15  The impact of high dust depletion on cold gas ...      reasoning
# 16  Our results demonstrate that even the environm...      reasoning
# 17  $\Omega_{\rm{m}}=0.305^{+0.055}_{-0.038}$ and ...      reasoning
# 18  Future SKA-era PTAs have the potential to dete...  multi_context
# 19                                                NaN  multi_context
# 20  Possible systematical effects are far from eno...  multi_context
# 21  The factors that determine the pattern speed o...  multi_context
# 22  The optimal Doppler parameter for the cold gas...  multi_context
# 23  The optimal survey strategy for weak lensing s...  multi_context
# 24  We provide, for the first time, a list of key ...         simple
#
#                                              metadata  episode_done
# 0   [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 1   [{'id': '1910.03566', 'title': 'Strong Lensing...          True
# 2   [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 3   [{'id': '1107.0187', 'title': 'Star Formation ...          True
# 4   [{'id': '1301.5870', 'title': 'Groups of two g...          True
# 5   [{'id': '1109.4536', 'title': 'Optimising cosm...          True
# 6   [{'id': '1005.4941', 'title': 'Weak lensing fr...          True
# 7   [{'id': '1002.2149', 'title': 'High molecular ...          True
# 8   [{'id': '0912.2746', 'title': 'Halo Gas and Ga...          True
# 9   [{'id': '1004.2790', 'title': 'The XMM-Newton ...          True
# 10  [{'id': '1106.1676', 'title': 'Molecular Gas i...          True
# 11  [{'id': '2005.05327', 'title': 'Inevitable imp...          True
# 12  [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 13  [{'id': '1907.12132', 'title': 'Impact of $1/f...          True
# 14  [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 15  [{'id': '0908.3485', 'title': 'Direct Evidence...          True
# 16  [{'id': '1301.5870', 'title': 'Groups of two g...          True
# 17  [{'id': '2010.01138', 'title': 'Dark Energy Su...          True
# 18  [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 19  [{'id': '1910.03566', 'title': 'Strong Lensing...          True
# 20  [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 21  [{'id': '1104.5693', 'title': 'The relation be...          True
# 22  [{'id': '0908.3485', 'title': 'Direct Evidence...          True
# 23  [{'id': '1312.5618', 'title': 'Probing the acc...          True
# 24  [{'id': '1010.2868', 'title': 'Deuterated spec...          True

# %%
df_test.head()
# Out:
#                                             question  \
# 0  What is the potential of future SKA-era PTAs i...
# 1  What are the potential constraints on the natu...
# 2  How is a temperature map used to derive an ang...
# 3  What are the star formation properties in the ...
# 4  What is the predicted red excess in galaxy col...
#
#                                             contexts  \
# 0  ['Prospects for Constraining interacting dark ...
# 1  ['Strong Lensing Time Delay Constraints on Dar...
# 2  ['New evidence for lack of CMB power on large ...
# 3  ['Star Formation Properties in Barred Galaxies...
# 4  ['Groups of two galaxies in SDSS: implications...
#
#                                         ground_truth evolution_type  \
# 0  The future SKA-era PTAs have the potential to ...         simple
# 1                                                NaN         simple
# 2  A temperature map is used to derive an angular...         simple
# 3  Under the effects of both a stellar bar and a ...         simple
# 4                0.15,$\pm$,0.01 and 0.14,$\pm$,0.01         simple
#
#                                             metadata  episode_done
# 0  [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 1  [{'id': '1910.03566', 'title': 'Strong Lensing...          True
# 2  [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 3  [{'id': '1107.0187', 'title': 'Star Formation ...          True
# 4  [{'id': '1301.5870', 'title': 'Groups of two g...          True

# %% [markdown]
# **Note** Some ground-truths are nan (why?), remove these before proceeding

# %% [markdown]
# ### Create the RAG Application

# %%
model_name = "sentence-transformers/all-MiniLM-l6-v2"
model_kwargs = {"device": "cpu"} # Since we are running on local machine, we will use CPU

embeddings = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)

vectordb = Chroma(persist_directory='./arxiv_cosmo_chroma_db_22k', embedding_function=embeddings)
retriever = vectordb.as_retriever()

llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
def get_rag_response(question):

    # Define the RAG template and chain
    template = """"You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question."
    "If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise."
    "\nQuestion: {question} \nContext: {context} \nAnswer:"
    """

    # The above prompt is the same as we get from prompt = hub.pull("rlm/rag-prompt")

    prompt = ChatPromptTemplate.from_template(template)

    chain = (
        {"context": retriever, "question": RunnablePassthrough()}
        | prompt
        | llm
        | StrOutputParser()
    )

    return chain.invoke(question)

# %%
get_rag_response("What is a Galaxy Cluster?")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 'A galaxy cluster is a large group of galaxies held together by gravity. They are the largest known gravitationally bound structures in the universe. Galaxy clusters can contain hundreds to thousands of galaxies.'

# %% [markdown]
# ### Run the RAG application to get responses and append to the synthetic dataset
#
# Reference: https://towardsdatascience.com/evaluating-rag-applications-with-ragas-81d67b0ee31a

# %%
df_test.dropna(subset=['ground_truth'], inplace=True)
df_test.reset_index(drop=True, inplace=True)
df_test.shape
# Out:
# (21, 6)

# %%
df_test
# Out:
#                                              question  \
# 0   What is the potential of future SKA-era PTAs i...
# 1   How is a temperature map used to derive an ang...
# 2   What are the star formation properties in the ...
# 3   What is the predicted red excess in galaxy col...
# 4   How can upcoming photometric large scale struc...
# 5   What are the cosmological constraints obtained...
# 6   What is the average fraction of cold gas relat...
# 7   What is the relationship between rotation curv...
# 8   What is the focus of the XMM-Newton Wide-Field...
# 9   How does the patchiness in the spatial distrib...
# 10  How can future SKA-era PTAs contribute to dete...
# 11  How does $1/f$ noise impact SKA intensity mapp...
# 12  What is the impact of high dust depletion on c...
# 13  What is the impact of the environment on galax...
# 14  What cosmological parameters are obtained from...
# 15  What can future SKA-era PTAs do to detect supe...
# 16  What explains the lower amplitudes of the low ...
# 17  What factors determine the pattern speed of th...
# 18  What is the optimal Doppler parameter for the ...
# 19  What is the optimal survey strategy for weak l...
# 20  How does redshift affect the detectability of ...
#
#                                              contexts  \
# 0   ['Prospects for Constraining interacting dark ...
# 1   ['New evidence for lack of CMB power on large ...
# 2   ['Star Formation Properties in Barred Galaxies...
# 3   ['Groups of two galaxies in SDSS: implications...
# 4   ['Optimising cosmic shear surveys to measure m...
# 5   ['Weak lensing from space: first cosmological ...
# 6   ["High molecular gas fractions in normal massi...
# 7   ['Halo Gas and Galaxy Disk Kinematics Derived ...
# 8   ['The XMM-Newton Wide-Field Survey in the COSM...
# 9   ['Inevitable imprints of patchy reionization o...
# 10  ['Prospects for Constraining interacting dark ...
# 11  ['Impact of $1/f$ noise on cosmological parame...
# 12  ['Direct Evidence of Cold Gas in DLA 0812+32B ...
# 13  ['Groups of two galaxies in SDSS: implications...
# 14  ['Dark Energy Survey Year 1 Results: Cosmologi...
# 15  ['Prospects for Constraining interacting dark ...
# 16  ['New evidence for lack of CMB power on large ...
# 17  ['The relation between dynamics and star forma...
# 18  ['Direct Evidence of Cold Gas in DLA 0812+32B ...
# 19  ['Probing the accelerating Universe with radio...
# 20  ['Deuterated species in extragalactic star-for...
#
#                                          ground_truth evolution_type  \
# 0   The future SKA-era PTAs have the potential to ...         simple
# 1   A temperature map is used to derive an angular...         simple
# 2   Under the effects of both a stellar bar and a ...         simple
# 3                 0.15,$\pm$,0.01 and 0.14,$\pm$,0.01         simple
# 4   We consider how upcoming photometric large sca...         simple
# 5   The cosmological constraints obtained from the...         simple
# 6   The average fraction of cold gas relative to t...         simple
# 7   The majority of the absorption velocities of M...         simple
# 8   The focus of the XMM-Newton Wide-Field Survey ...         simple
# 9   The patchiness in the spatial distribution of ...         simple
# 10  Future SKA-era PTAs can contribute to detectin...      reasoning
# 11  $1/f$ noise degrades the projected constraints...      reasoning
# 12  The impact of high dust depletion on cold gas ...      reasoning
# 13  Our results demonstrate that even the environm...      reasoning
# 14  $\Omega_{\rm{m}}=0.305^{+0.055}_{-0.038}$ and ...      reasoning
# 15  Future SKA-era PTAs have the potential to dete...  multi_context
# 16  Possible systematical effects are far from eno...  multi_context
# 17  The factors that determine the pattern speed o...  multi_context
# 18  The optimal Doppler parameter for the cold gas...  multi_context
# 19  The optimal survey strategy for weak lensing s...  multi_context
# 20  We provide, for the first time, a list of key ...         simple
#
#                                              metadata  episode_done
# 0   [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 1   [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 2   [{'id': '1107.0187', 'title': 'Star Formation ...          True
# 3   [{'id': '1301.5870', 'title': 'Groups of two g...          True
# 4   [{'id': '1109.4536', 'title': 'Optimising cosm...          True
# 5   [{'id': '1005.4941', 'title': 'Weak lensing fr...          True
# 6   [{'id': '1002.2149', 'title': 'High molecular ...          True
# 7   [{'id': '0912.2746', 'title': 'Halo Gas and Ga...          True
# 8   [{'id': '1004.2790', 'title': 'The XMM-Newton ...          True
# 9   [{'id': '2005.05327', 'title': 'Inevitable imp...          True
# 10  [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 11  [{'id': '1907.12132', 'title': 'Impact of $1/f...          True
# 12  [{'id': '0908.3485', 'title': 'Direct Evidence...          True
# 13  [{'id': '1301.5870', 'title': 'Groups of two g...          True
# 14  [{'id': '2010.01138', 'title': 'Dark Energy Su...          True
# 15  [{'id': '2210.04000', 'title': 'Prospects for ...          True
# 16  [{'id': '0911.4063', 'title': 'New evidence fo...          True
# 17  [{'id': '1104.5693', 'title': 'The relation be...          True
# 18  [{'id': '0908.3485', 'title': 'Direct Evidence...          True
# 19  [{'id': '1312.5618', 'title': 'Probing the acc...          True
# 20  [{'id': '1010.2868', 'title': 'Deuterated spec...          True

# %%
questions = df_test['question'].tolist()
questions
# Out:
# ['What is the potential of future SKA-era PTAs in detecting supermassive black hole binaries?',
#  'How is a temperature map used to derive an angular power spectrum in the study of the CMB power on large scales?',
#  'What are the star formation properties in the barred galaxy NGC 7479?',
#  'What is the predicted red excess in galaxy colour for the delayed-then-rapid star formation quenching scenario in the -19 and -20 samples?',
#  'How can upcoming photometric large scale structure surveys be optimized to measure modifications to gravity on cosmic scales?',
#  'What are the cosmological constraints obtained from the measurement of three-point shear statistics in weak lensing from space?',
#  'What is the average fraction of cold gas relative to total galaxy baryonic mass in typical massive star forming galaxies at <z>~1.2 and 2.3?',
#  'What is the relationship between rotation curves and MgII absorption selected galaxies at intermediate redshift?',
#  'What is the focus of the XMM-Newton Wide-Field Survey in the COSMOS field?',
#  'How does the patchiness in the spatial distribution of electrons affect the amplitude of the kinematic Sunyaev-Zeldovich (kSZ) signal?',
#  'How can future SKA-era PTAs contribute to detecting supermassive black hole binaries and constraining cosmological parameters?',
#  "How does $1/f$ noise impact SKA intensity mapping's projected constraints on cosmological parameters, and which redshift and scale ranges are most affected?",
#  'What is the impact of high dust depletion on cold gas in DLA 0812+32B?',
#  'What is the impact of the environment on galaxy evolution in sparse galaxy groups, based on observations of isolated and paired galaxies?',
#  'What cosmological parameters are obtained from the joint analysis of cluster abundances and auto/cross correlations of three cosmic tracer fields in the Dark Energy Survey Year 1 Results?',
#  'What can future SKA-era PTAs do to detect supermassive black hole binaries and how does this relate to constraining interacting dark energy cosmology?',
#  "What explains the lower amplitudes of the low multipoles in the preliminary Planck power spectrum compared to the WMAP team's findings, given the absence of large angular correlations in the CMB temperature field?",
#  'What factors determine the pattern speed of the bar or spiral in the analysis of barred spiral galaxies, considering star formation and dynamics?',
#  'What is the optimal Doppler parameter for the cold gas in DLA 0812+32B, considering direct evidence and property analysis?',
#  'What is the optimal survey strategy for weak lensing science in the VLASS deep fields program, considering the unique strengths of the JVLA and its resolution and sensitivity?',
#  'How does redshift affect the detectability of deuterated species in extragalactic star-forming regions?']

# %%
question = questions[0]
question
# Out:
# 'What is the potential of future SKA-era PTAs in detecting supermassive black hole binaries?'

# %%
get_rag_response(question)
# Out:
# 'The potential of future SKA-era PTAs in detecting supermassive black hole binaries is significant. These PTAs have the ability to detect Nanohertz gravitational waves generated by individual inspiraling supermassive black hole binaries. The SKA will collect gravitational wave signals from thousands of massive systems, being able to individually resolve and locate several of them.'

# %%
retriever.get_relevant_documents(question)[0]
# Out:
# Document(page_content='Electromagnetic signatures of supermassive black hole binaries resolved   by PTAs', metadata={'abstract': "Pulsar timing arrays (PTAs) may eventually be able to detect not only the stochastic gravitational-wave (GW) background of SMBH binaries, but also individual, particularly massive binaries whose signals stick out above the background. In this contribution, we discuss the possibility of identifying and studying such `resolved' binaries through their electromagnetic emission. The host galaxies of such binaries are themselves expected to be also very massive and rare, so that out to redshifts z~2 a unique massive galaxy may be identified as the host. At higher redshifts, the PTA error boxes are larger and may contain as many as several hundred massive-galaxy interlopers. In this case, the true counterpart may be identified, if it is accreting gas efficiently, as an active galactic nucleus (AGN) with a peculiar spectrum and variable emission features. Specifically, the binary's tidal torques expel the gas from the inner part of the accretion disk, making it unusually dim in X-ray and UV bands and in broad optical emission lines. The tails of the broad wings of any FeK-alpha emission line may also be `clipped' and missing. The binary's orbital motion, as well as the gas motions it induces, may trigger quasiperiodic variations. These include coherent flux variability, such as luminous, multi-wavelength flares, as well as Doppler shifts of broad emission lines and `see-saw' oscillations in the FeK-alpha line. Additional features, such as evidence for a recent major merger or dual collimated jets, could also corroborate the counterpart. These properties would make resolved PTA sources stand out among AGN with similar overall luminosities and allow their identification.", 'cat_text': 'Cosmology and Nongalactic Astrophysics', 'categories': 'astro-ph.CO', 'id': '1309.2302', 'title': 'Electromagnetic signatures of supermassive black hole binaries resolved   by PTAs'})

# %%
responses=[]
contexts=[]

# Inference
for query in questions:
  responses.append(get_rag_response(query))
  contexts.append([docs.page_content for docs in retriever.get_relevant_documents(query)])

# %%
responses[0]
# Out:
# 'The potential of future SKA-era PTAs in detecting supermassive black hole binaries is significant. These PTAs have the ability to detect Nanohertz gravitational waves generated by individual inspiraling supermassive black hole binaries. The SKA will collect gravitational wave signals from thousands of massive systems, being able to individually resolve and locate several of them.'

# %%
contexts[0]
# Out:
# ['Electromagnetic signatures of supermassive black hole binaries resolved   by PTAs',
#  'parameters. In this paper, we analyze the ability of future SKA-era PTAs to detect the existing SMBHBs candidates assuming the root mean square of timing noise $\\sigma_t=20\\ {\\rm ns}$, and use the',
#  'arrays (PTAs), are particularly appealing multimessenger carriers. According to current models for massive black hole formation and evolution, the planned Square Kilometer Array (SKA) will collect',
#  'The Future of Direct Supermassive Black Hole Mass Estimates']

# %%
ground_truths = df_test['ground_truth'].tolist()
ground_truths[0]
# Out:
# 'The future SKA-era PTAs have the potential to detect Nanohertz gravitational waves (GWs) generated by the individual inspiraling supermassive black hole binaries (SMBHBs) in the galactic centers.'

# %% [markdown]
# **Note** Incorporate these retrieved contexts now, for later try and use the contexts in the synthetic dataset -> What is the difference?

# %%
df_test.iloc[0]['contexts']
# Out:
# "['Prospects for Constraining interacting dark energy cosmology with   gravitational-wave bright sirens detected by future SKA-era pulsar timing   arrays \\n Pulsar timing arrays (PTAs) have the potential to detect Nanohertz gravitational waves (GWs) that are usually generated by the individual inspiraling supermassive black hole binaries (SMBHBs) in the galactic centers. The GW signals as cosmological standard sirens can provide the absolute cosmic distances, thereby can be used to constrain the cosmological parameters. In this paper, we analyze the ability of future SKA-era PTAs to detect the existing SMBHBs candidates assuming the root mean square of timing noise $\\\\sigma_t=20\\\\ {\\\\rm ns}$, and use the simulated PTA data to constrain the interacting dark energy (IDE) models with energy transfer rate $Q = \\\\beta H\\\\rho_c$. We find that, the future SKA-era PTAs will play an important role in constraining the IDE cosmology. Using only the mock PTA data consisting of 100 pulsars, we obtain $\\\\sigma(H_0)=0.239\\\\ {\\\\rm km} \\\\ {\\\\rm s}^{-1} {\\\\rm Mpc}^{-1}$ and $\\\\sigma(\\\\Omega_m)=0.0103$ in the I$\\\\Lambda$CDM model, which are much better than the results from the Planck TT, TE, EE+lowE. However, the PTA data cannot provide a tight constraint on the coupling parameter $\\\\beta$ compared with Planck, but the data combination of Planck+PTA can provide a rather tight constraint, i.e., $\\\\sigma(\\\\beta)=0.00232$, since the PTA data could break the parameter degeneracies inherent in CMB. In the I$w$CDM model, we obtain $\\\\sigma(\\\\beta)=0.00137$ and $\\\\sigma(w)=0.0492$ from the Planck+PTA data combination. In addition, we also find that with the increase of the number of pulsars in PTA, the constraint results from the Planck+PTA will be further improved to some extent. We show that the observations of Nanohertz GWs with future SKA-era PTAs will provide a powerful tool for exploring the nature of dark energy and measuring the coupling between dark energy and dark matter.']"

# %%
data = {'question': questions, 'answer': responses, 'contexts': contexts, 'ground_truth': ground_truths  }
dataset_for_eval = Dataset.from_dict(data)

dataset_for_eval
# Out:
# Dataset({
#     features: ['question', 'answer', 'contexts', 'ground_truth'],
#     num_rows: 21
# })

# %%
result = evaluate(
    dataset = dataset_for_eval, 
    metrics=[
        context_precision,
        context_recall,
        faithfulness,
        answer_relevancy,
    ],
)

df = result.to_pandas()
# Out:
# Evaluating:  14%|█▍        | 12/84 [00:12<01:00,  1.20it/s]Failed to parse output. Returning None.
# Evaluating:  21%|██▏       | 18/84 [00:14<00:40,  1.63it/s]No statements were generated from the answer.
# Evaluating:  33%|███▎      | 28/84 [00:17<00:27,  2.04it/s]No statements were generated from the answer.
# Evaluating:  94%|█████████▍| 79/84 [00:32<00:01,  3.75it/s]Failed to parse output. Returning None.
# Evaluating: 100%|██████████| 84/84 [00:36<00:00,  2.28it/s]

# %%
df
# Out:
#                                              question  \
# 0   What is the potential of future SKA-era PTAs i...
# 1   How is a temperature map used to derive an ang...
# 2   What are the star formation properties in the ...
# 3   What is the predicted red excess in galaxy col...
# 4   How can upcoming photometric large scale struc...
# 5   What are the cosmological constraints obtained...
# 6   What is the average fraction of cold gas relat...
# 7   What is the relationship between rotation curv...
# 8   What is the focus of the XMM-Newton Wide-Field...
# 9   How does the patchiness in the spatial distrib...
# 10  How can future SKA-era PTAs contribute to dete...
# 11  How does $1/f$ noise impact SKA intensity mapp...
# 12  What is the impact of high dust depletion on c...
# 13  What is the impact of the environment on galax...
# 14  What cosmological parameters are obtained from...
# 15  What can future SKA-era PTAs do to detect supe...
# 16  What explains the lower amplitudes of the low ...
# 17  What factors determine the pattern speed of th...
# 18  What is the optimal Doppler parameter for the ...
# 19  What is the optimal survey strategy for weak l...
# 20  How does redshift affect the detectability of ...
#
#                                                answer  \
# 0   The potential of future SKA-era PTAs in detect...
# 1   A temperature map is used to derive an angular...
# 2   The star formation properties in the barred ga...
# 3   The predicted red excess in galaxy colour for ...
# 4   To optimize upcoming photometric large scale s...
# 5   The cosmological constraints obtained from the...
# 6   The average fraction of cold gas relative to t...
# 7   The relationship between rotation curves and M...
# 8   The focus of the XMM-Newton Wide-Field Survey ...
# 9   The patchiness in the spatial distribution of ...
# 10  Future SKA-era PTAs can contribute to detectin...
# 11  $1/f$ noise degrades projected constraints on ...
# 12  I don't know the impact of high dust depletion...
# 13  The impact of the environment on galaxy evolut...
# 14  The cosmological parameters obtained from the ...
# 15  Future SKA-era PTAs can detect supermassive bl...
# 16  The lower amplitudes of the low multipoles in ...
# 17  The pattern speed of the bar or spiral in barr...
# 18  The optimal Doppler parameter for the cold gas...
# 19  The optimal survey strategy for weak lensing s...
# 20  I don't know how redshift affects the detectab...
#
#                                              contexts  \
# 0   [Electromagnetic signatures of supermassive bl...
# 1   [Level correlations of the CMB temperature ang...
# 2   [Galaxy Evolution Explorer and infrared data f...
# 3   [in a group of two, we find a red excess attri...
# 4   [We consider how upcoming photometric large sc...
# 5   [Weak lensing from space: first cosmological c...
# 6   [cosmic epoch. The average fraction of cold ga...
# 7   [galaxies at low to moderate redshift. An anal...
# 8   [We report the final optical identifications o...
# 9   [and spatial fluctuations in the electron dens...
# 10  [The Future of Direct Supermassive Black Hole ...
# 11  [Impact of $1/f$ noise on cosmological paramet...
# 12  [Direct Evidence of Cold Gas in DLA 0812+32B, ...
# 13  [Effects on Galaxy Evolution: Pair Interaction...
# 14  [analysis of cluster abundances and auto/cross...
# 15  [Electromagnetic signatures of supermassive bl...
# 16  [A number of studies of WMAP and Planck have h...
# 17  [Determining Star Formation Timescale and Patt...
# 18  [Direct Evidence of Cold Gas in DLA 0812+32B, ...
# 19  [as the optimal survey strategy from the point...
# 20  [of photometric redshifts for extragalactic ob...
#
#                                          ground_truth  context_precision  \
# 0   The future SKA-era PTAs have the potential to ...               1.00
# 1   A temperature map is used to derive an angular...               1.00
# 2   Under the effects of both a stellar bar and a ...               1.00
# 3                 0.15,$\pm$,0.01 and 0.14,$\pm$,0.01               1.00
# 4   We consider how upcoming photometric large sca...               1.00
# 5   The cosmological constraints obtained from the...               1.00
# 6   The average fraction of cold gas relative to t...               1.00
# 7   The majority of the absorption velocities of M...               1.00
# 8   The focus of the XMM-Newton Wide-Field Survey ...               1.00
# 9   The patchiness in the spatial distribution of ...               1.00
# 10  Future SKA-era PTAs can contribute to detectin...               1.00
# 11  $1/f$ noise degrades the projected constraints...               1.00
# 12  The impact of high dust depletion on cold gas ...               1.00
# 13  Our results demonstrate that even the environm...               1.00
# 14  $\Omega_{\rm{m}}=0.305^{+0.055}_{-0.038}$ and ...               1.00
# 15  Future SKA-era PTAs have the potential to dete...               1.00
# 16  Possible systematical effects are far from eno...               1.00
# 17  The factors that determine the pattern speed o...               1.00
# 18  The optimal Doppler parameter for the cold gas...               0.75
# 19  The optimal survey strategy for weak lensing s...               1.00
# 20  We provide, for the first time, a list of key ...               1.00
#
#     context_recall  faithfulness  answer_relevancy
# 0              1.0      1.000000          1.000000
# 1              0.0      1.000000          0.930677
# 2              1.0      1.000000          0.983760
# 3              1.0      0.800000          1.000000
# 4              1.0      1.000000          0.931891
# 5              1.0      0.571429          0.999999
# 6              1.0      1.000000          0.994973
# 7              1.0      0.250000          0.991793
# 8              1.0      0.500000          1.000000
# 9              1.0      0.400000          0.947822
# 10             1.0      1.000000          0.892551
# 11             NaN           NaN          0.953922
# 12             0.0           NaN          0.000000
# 13             1.0      1.000000          0.953625
# 14             0.0      1.000000          0.996699
# 15             1.0      1.000000          0.965058
# 16             1.0      1.000000          0.955711
# 17             1.0      0.666667          0.958977
# 18             0.0      0.500000          0.975082
# 19             1.0      1.000000          0.980399
# 20             1.0           NaN          0.000000

# %% [markdown]
# #### So we have the final RAG evaluations table; next step is to spend some time understanding these metrics and the assumptions behind them.

# %% [markdown]
# ### Things to Explore::
# * Different LLMs, generator, critic, RAG
# * How do we summarize performance?
# * Should we consider type of evolution while summarizing?
# * Most efficient way to write a pipeline from this
